# %% [markdown]
# Question 1
# =
# New pledge in main repo

# %% [markdown]
# Question 2
# =

# %% [markdown]
# a)
# -

# %%
theta = arange(-pi,pi+.1,.1) #defining the given parameters of theta
y = (cos(2*theta)*cos(theta/2))**2 #defining the equation given

# %%
plot(theta,y,'r-') #plotting the equation red
plot(theta,y,'b*') #plotting the equation blue star
xlim(-pi,pi+.1,.1) #seting the limits of x to be from -pi to pi
xlabel("$\theta (rad)$") #labeling the x axis
ylabel("Intensity") #labeling the y axis
theta = array([-4,-3,-2,-1,0,1,2,3,4]) #seting the right number of tick marks
my_xticks=['$-\pi$','$-\pi*3/4$','$-\pi/2$','$-\pi/4$','$0$','$-pi/4$','$\pi/2$','$\pi*3/4$','$\pi$'] # correctly naming said tick marks
xticks(theta, my_xticks) #implementing the tick marks
show()

# %% [markdown]
# b)
# -

# %%
t = arange(-5,5.1,.1) #setting parameters
f= lambda t: (t+1)/(t-1) #defining f(t)
g = lambda t: exp(-t) #defining g(t)
plot(t,f(t), label = '(t+1)/(t-1)') #plotting f(t)
plot(t,g(t), 'r-.', label = 'exp(-t)') #plotting g(t)
xlim(-5,5.1,.1) #setting x limits
ylim(-10,10.1,.1) #setting y limits
xlabel("time (seconds)",fontsize=13) #labeling x axis
ylabel("f(t),g(t)", fontsize=13) #labeling y axis
text(1.3,-4,'discontinuous') #adding the discontinous text
text(1.3,-5,'here')
legend(loc="lower left") #adding the legend
show()

# %% [markdown]
# Question 3
# =
# Modification of Week4/Electrostatics.py file

# %% [markdown]
# a)
# -

# %%
from Electrostatics import * #attempting to import Electrostatics
from scipy import integrate # importing the integrate functions
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-154-3605de7a990e> in <module>()
# ----> 1 from Electrostatics import *
#       2 from scipy import integrate
#
# ImportError: No module named Electrostatics

# %%
#Manually writing out the new equation from electrostatics
def pointField(x,y,q,Xq,Yq): #Defining the function
    k=8.99e9  #defining k

    Ex=(k*q*(x-Xq))/((x-Xq)**2+(y-Yq)**2)**(1/2.) #Writing the equations
    Ey=(k*q*(y-Yq))/((x-Xq)**2+(y-Yq)**2)**(1/2.)
    return {"Ex(x,y)":Ex, "Ey(x,y)":Ey }   #This will return my function
                                           #in an easy to read manner

# %% [markdown]
# b)
# -

# %%
#Ran out of time to finish this problem with an integral
a=1 #meter
b=2 #meters
L = 1.*10**(-6) # Coulombs/meters
k=8.99*10**(9)
#q=L
x=3
y=3
#integrate.quad(pointField(3,3,L,Xq,Yq),a,b)
print pointField(x,y,L,1,2)
# Out:
# {'Ex(x,y)': 8040.900447089243, 'Ey(x,y)': 4020.4502235446216}
# 8990.0

# %% [markdown]
# c)
# -

# %%
#Ran out of time to finish this problem with an integral
a=1 #meter
b=3 #meters
L_0 = 2*10**(-6) #Coulombs/meters
x= 5
y=3
L_x = L_0*x**2/b**2
pointField(x,y,L_x,a,b)
# Out:
# {'Ex(x,y)': 49944.44444444444, 'Ey(x,y)': 0.0}

# %% [markdown]
# Question 4
# =

# %% [markdown]
# a)
# -

# %%
prefixes = 'JKLMNOPQ'
suffix = 'ack'

for letter in prefixes:
    if letter == 'O':
        print letter + 'u' + suffix #adds the u after O
    elif letter == 'Q':
        print letter + 'u' + suffix #adds the u after Q
    else:
        print letter + suffix
# Out:
# Jack
# Kack
# Lack
# Mack
# Nack
# Ouack
# Pack
# Quack

# %% [markdown]
# b)
# -

# %%
def is_anagram(s1,s2): # defining the anagram function
    return sorted(list(s1.replace('', ''))) == sorted(list(s2.replace('', ''))) # returns the Boolean of whether or not the rearanged list 
                                                                                # of s1 equals the rearanged list of s2
#test cases
print is_anagram('apple', 'pplea')
print is_anagram('loper', 'kpoer')
print is_anagram('meat', 'team')
print is_anagram('hey', 'hefnekljbnh')
# Out:
# True
# False
# True
# False
