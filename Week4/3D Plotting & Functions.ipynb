# %% [markdown]
# Electric Potential
# =

# %% [markdown]
# The dipole potential is just the sum of the potentials from two point charges sepparated by some distance. We'll consider a pair of point charges +- q located at x=0, y=+-d.

# %% [markdown]
# $V(x,y) = \frac{kq}{\sqrt{x^2 + (y-d)^2}}-\frac{kq}{\sqrt{x^2 + (y+d)^2}}$

# %% [markdown]
# Recall that k = 1/4$\pi\epsilon_0$. To see what is happening we will just let k=1, q=1, d=1. The answer won't depend in an important way on these choices.

# %%
#make the x-y grid to cover the plane -2<x<2 and -2<y<2
dx = 0.06
dy = 0.06
x = arange(-2.,2.,dx)
y = arange(-2.,2.,dy)
X,Y = meshgrid(x,y)
#Make function V(x,y)
k = 1; q = 1; d = 1
V = (k*q/ (X**2 + (Y-d)**2)**(1/2.)) - (k*q/ (X**2 + (Y + d)**2)**(1/2.))
from mpl_toolkits.mplot3d import Axes3D
fig = figure()
ax = fig.gca(projection='3d')
p = ax.plot_surface(X, Y, V, rstride = 1, cstride=1, linewidth=0, cmap=cm.flag)
cb = fig.colorbar(p,shrink=0.55)

# %%
#Represent 3D data by contours
levels = array([8,4,2,1,0.5,0.25,0,-0.25,-0.5,-1,-2,-4,-8])
contour(X,Y,V,levels, linewidths=4, cmap=cm.flag)
show()

# %% [markdown]
# ##Ex 1. Make a 3-D plot of the function $G(x,y) = e^(-x^2-y^2)$ over the range $-6< (x,y)< 6$ using 51 bins in x and 51 bins in y.

# %%
dx = .51
dy = .51
x = arange(-6.,6.,dx)
y = arange(-6.,6.,dy)
X,Y = meshgrid(x,y)
G = e**(-X**2 - Y**2)

from mpl_toolkits.mplot3d import Axes3D
fig = figure()
ax = fig.gca(projection='3d')
p = ax.plot_surface(X, Y, G, rstride = 1, cstride=1, linewidth=0, cmap=cm.seismic)
cb = fig.colorbar(p,shrink=0.5)
cse = ax.contour(X,Y,G, array([0,.2,.4,.6,.8]), zdir ="x", offset=-6)

# %% [markdown]
# ##Ex. 2 Determine the electric potential for a quadrapole consisting of q= -1.0 nC at both (x=+-2m, y=0) and q= +1.0 nC at both (x=0, y=+-2m). Make a surface plot and a contour plot on the range -4 < x,y < 4 using 101 bins in x and 101 bins in y.

# %%
k = 8.9875518*10**9 #N*m^2/C^2
q = 1*10**(-9) # Coulombs
d = +- 2 #meters
dx = .101
dy = .101
x = arange(-4.,4.,dx)
y = arange(-4.,4.,dy)
X,Y = meshgrid(x,y)
V = (k*q/ (X**2 + (Y-d)**2)**(1/2.)) + (k*q/ (X**2 + (Y + d)**2)**(1/2.))-(k*q/ (Y**2 + (X-d)**2)**(1/2.)) - (k*q/ (Y**2 + (X + d)**2)**(1/2.))

from mpl_toolkits.mplot3d import Axes3D
fig = figure()
ax = fig.gca(projection='3d')

p = ax.plot_surface(X, Y, V, rstride = 1, cstride=1, linewidth=0, cmap=cm.flag)
cb = fig.colorbar(p,shrink=0.5)

# %%
levels = array([16,8,4,2,1,0.5,0.25,0,-0.25,-0.5,-1,-2,-4,-8,-16])
contour(X,Y,V,levels, linewidths=3, cmap=cm.seismic)
show()

# %% [markdown]
# Question 3
# ==

# %%
def pointPotential(x,y,q,posx,posy):
    k=1
    Vpp = (k*q/(x**2 +(y-(posx**2+posy**2)**(1/2))**2))
    return Vpp

# %%
x = 1.; y = 1.
V11 = pointPotential(x,y,1e-9,0.,0.)
print V11
# Out:
# 1e-09

# %%
x,y = meshgrid(arange(-2.,2.,0.06),arange(-2.,2.,0.06))
Vxy = pointPotential(x,y,1e-9,0.,0.)
print Vxy
# Out:
# [[  7.69230769e-11   7.83478016e-11   7.97804442e-11 ...,   8.07389226e-11
#     7.93021412e-11   7.78719163e-11]
#  [  7.90913980e-11   8.05983622e-11   8.21152899e-11 ...,   8.31310478e-11
#     8.16086701e-11   8.00948323e-11]
#  [  8.13378449e-11   8.29324930e-11   8.45394292e-11 ...,   8.56164384e-11
#     8.40025537e-11   8.23994726e-11]
#  ...,
#  [  2.12512751e-10   2.23753692e-10   2.35849057e-10 ...,   2.44427063e-10
#     2.31717490e-10   2.19915552e-10]
#  [  2.07900208e-10   2.18646143e-10   2.30181383e-10 ...,   2.38344933e-10
#     2.26244344e-10   2.14979792e-10]
#  [  2.03185956e-10   2.13438060e-10   2.24416517e-10 ...,   2.32169391e-10
#     2.20672610e-10   2.09942896e-10]]

# %% [markdown]
# b)
# -

# %%
def dipolePotential(x,y,q,d):
    Vdp = (k*q/ (x**2 + (y-d)**2)**(1/2.)) - (k*q/ (x**2 + (y + d)**2)**(1/2.))
    return Vdp

# %%
x = 1.; y = 1.
V22 = dipolePotential(x,y,1e-9,3)
print V22
# Out:
# 1.83955386186

# %%
x,y = meshgrid(arange(-2.,2.,0.06),arange(-2.,2.,0.06))
Vd2 = dipolePotential(x,y,1e-9,3)
print Vd2
# Out:
# [[-2.35040888 -2.44208999 -2.53816332 ..., -2.60476394 -2.50563702
#   -2.41105256]
#  [-2.28420144 -2.37203648 -2.46392546 ..., -2.52753069 -2.4328337
#   -2.34231697]
#  [-2.21670145 -2.30070651 -2.38844176 ..., -2.44908179 -2.35877253
#   -2.2722981 ]
#  ...,
#  [ 2.17107433  2.25254348  2.33753573 ...,  2.39622218  2.30880505
#    2.22500243]
#  [ 2.23933351  2.32461235  2.41372759 ...,  2.47535182  2.38358592
#    2.29576804]
#  [ 2.30642359  2.39553977  2.48882111 ...,  2.55342216  2.45725217
#    2.3653814 ]]

# %% [markdown]
# c)
# -

# %%
x,y = meshgrid(arange(-2.,2.,0.06),arange(-2.,2.,0.06))
Vd2 = dipolePotential(x,y,1,1)
from mpl_toolkits.mplot3d import Axes3D
fig = figure()
ax = fig.gca(projection='3d')
p = ax.plot_surface(x, y, Vd2, rstride = 1, cstride=1, linewidth=0, cmap=cm.flag)
cb = fig.colorbar(p,shrink=0.55)

# %%
def dipolePotential(x,y,q,d):
    Vdp = (k*q/ (x**2 + (y-d)**2)**(1/2.)) + (k*q/ (x**2 + (y + d)**2)**(1/2.))
    return Vdp

# %%
x,y = meshgrid(arange(-4.,4.,0.101),arange(-4.,4.,0.101))
V44 = dipolePotential(x,y,1e-9,2) - dipolePotential(y,x,1e-9,2)
from mpl_toolkits.mplot3d import Axes3D
fig = figure()
ax = fig.gca(projection='3d')
p = ax.plot_surface(x, y, V44, rstride = 1, cstride=1, linewidth=0, cmap=cm.flag)
cb = fig.colorbar(p,shrink=0.55)
