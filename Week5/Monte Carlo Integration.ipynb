# %%
l = w = 4
r = 1.375
Nin = 15
N = 40
Aboard = l*w
Aexact = pi*r**2
Acirc = (Nin/float(N))*Aboard
print "Aboard=", Aboard
print "Aexact=", Aexact
print "Acirc=",Acirc
print "Error=", (100.*(Acirc-Aexact)/Aexact),"%"
# Out:
# Aboard= 16
# Aexact= 5.93957361069
# Acirc= 6.0
# Error= 1.01735230957 %

# %% [markdown]
# Example 1
# =

# %%
f = lambda x: x**(0.5) + sin(x)

# %%
x = arange(0.,15.,0.001)

# %%
myplot = plot(x,f(x),lw=3)
ylabel(r'$x^{1/2} + \sin(x)$', fontsize=20)
xlabel(r'$x$', fontsize=20)
xlim(0.,15.)

show()

# %%
xmin = 1.7
xmax = 12.4

subx = x[logical_and((x > xmin),(x < xmax))]
ymax = max(f(subx))*1.05
ymin = 0.

myplot = plot(x,f(x),lw=3)
xlim(0.,15.)

plot([xmin, xmin], [ymin,ymax], color = 'k', linestyle='--')
plot([xmax, xmax], [ymin,ymax], color = 'k', linestyle='--')
plot([xmin, xmax], [ymax,ymax], color = 'k', linestyle='--')
show()

# %%
N = 10000
samples_x = xmin + (xmax-xmin)*random_sample(N);
samples_y = ymin + (ymax-ymin)*random_sample(N);

myplot = plot(x,f(x),lw=3)
xlim(0.,15.)

plot(samples_x[1:200],samples_y[1:200],'.')

plot([xmin, xmin], [ymin,ymax], color = 'k', linestyle='--')
plot([xmax, xmax], [ymin,ymax], color = 'k', linestyle='--')
plot([xmin, xmax], [ymax,ymax], color = 'k', linestyle='--')
show()

# %%
newmask = (samples_y < f(samples_x))

# %%
sum(newmask)
# Out:
# 6223

# %%
myplot = plot(x,f(x),lw=3)
xlim(0.,15.)

plot(samples_x[1:200],samples_y[1:200],'.')

plot(samples_x[newmask[:200]],samples_y[newmask[:200]],'r.')

plot([xmin, xmin], [ymin,ymax], color = 'k', linestyle='--')
plot([xmax, xmax], [ymin,ymax], color = 'k', linestyle='--')
plot([xmin, xmax], [ymax,ymax], color = 'k', linestyle='--')
show()

# %%
I = (xmax-xmin)*(ymax-ymin)*sum(newmask)/newmask.size
print I
# Out:
# 26.6956244644

# %%
Iana = lambda x: (2./3.)*x**(3./2.) -cos(x)
Iexact = Iana(xmax)-Iana(xmin)
Ierr = 100*(Iexact-I)/(Iexact)
print "I_exaxt =", Iexact
print "I_hitormiss =", I
print "Error on I =", Ierr, "%"
# Out:
# I_exaxt = 26.5172145362
# I_hitormiss = 26.6956244644
# Error on I = -0.67280795271 %

# %% [markdown]
# Exercise 1
# =

# %%
N = 10000000
samples_x = xmin + (xmax-xmin)*random_sample(N);
samples_y = ymin + (ymax-ymin)*random_sample(N);

myplot = plot(x,f(x),lw=3)
xlim(0.,15.)

plot(samples_x[1:200],samples_y[1:200],'.')

plot([xmin, xmin], [ymin,ymax], color = 'k', linestyle='--')
plot([xmax, xmax], [ymin,ymax], color = 'k', linestyle='--')
plot([xmin, xmax], [ymax,ymax], color = 'k', linestyle='--')
show()

# %%
newmask = (samples_y < f(samples_x))

# %%
sum(newmask)
# Out:
# 6179370

# %%
myplot = plot(x,f(x),lw=3)
xlim(0.,15.)

plot(samples_x[1:200],samples_y[1:200],'.')

plot(samples_x[newmask[:200]],samples_y[newmask[:200]],'r.')

plot([xmin, xmin], [ymin,ymax], color = 'k', linestyle='--')
plot([xmax, xmax], [ymin,ymax], color = 'k', linestyle='--')
plot([xmin, xmax], [ymax,ymax], color = 'k', linestyle='--')
show()

# %%
I = (xmax-xmin)*(ymax-ymin)*sum(newmask)/newmask.size
print I
# Out:
# 26.5084590948

# %%
Iana = lambda x: (2./3.)*x**(3./2.) -cos(x)
Iexact = Iana(xmax)-Iana(xmin)
Ierr = 100*(Iexact-I)/(Iexact)
print "I_exaxt =", Iexact
print "I_hitormiss =", I
print "Error on I =", Ierr, "%"
print "Success!"
# Out:
# I_exaxt = 26.5172145362
# I_hitormiss = 26.5084590948
# Error on I = 0.0330179529584 %
# Success!

# %% [markdown]
# Exercise 2
# =

# %% [markdown]
# a)
# -

# %%
f = lambda x: x**(0.5) + sin(x)
N = 10000
a = 1.7
b = 12.4
x = arange(a,b,0.001) 
x_i = (b-a)*random_sample(N)+a
I_N = (b-a)*sum(f(x_i))/N
print I_N
# Out:
# 26.463167452

# %%
plot(x,f(x), label = "$y= x^{1/5}+sin(x)$")
avg = average(f(x))
axhline( y = avg, color = 'r', label ="$Average$")
legend(loc = "upper left")
show()

# %%
err = 100*(Iexact-I_N)/Iexact
print "Error for Sample Mean Method=", err, "%"
# Out:
# Error for Sample Mean Method= 0.203818859271 %

# %% [markdown]
# Example 2
# =

# %%
fxyz = lambda x,y,z: sqrt(x**2 + y**2 + z**2)
    
N = 1e6
L=1.; W=1.; H=1.
x = L*random_sample(N); y = W*random_sample(N); z= H*random_sample(N)

IntMC = (L*W*H/N)*sum(fxyz(x,y,z))

# %%
N = 10000
fsph = lambda r,phi: (cos(phi)/r**3)
    
phiMax = 2*pi; thetaMax = pi; rMax =1;
phi = phiMax*random_sample(N);
theta = thetaMax*random_sample(N);
r = rMax*random_sample(N);
Integral_MC = (phiMax*thetaMax*rMax/N)*sum(fsph(r,phi)*r**2*sin(theta))

# %% [markdown]
# Example 3
# =

# %%
import sys
sys.path.insert(0, "/Network/Servers/cp-file-home.cp-calpoly.edu/studentHome$/user/advice/PHYS-202-S13/Week4")
from Electrostatics1 import *

sigma = 1e-6; #charge density
N = 1e6;
x0 = 2.; # P(x0,y0)
y0 = 3.;
xi = -1 + 1.001*random_sample(N); #-1<x<1
yi = 0. + 2.001*random_sample(N); #0<y<2

Vi = pointPotential(x0,y0,sigma,xi,yi);

Vtot = (2.*2./N)*sum(Vi) #range is 2 in x and y
print Vtot
# Out:
# 35600.0

# %% [markdown]
# Exercise 3
# =

# %%
sigma = 2e-9; #charge density
N = 1e6;
x0 = 2.; # P(x0,y0)
y0 = 3.;
xi = 0 + .01201*random_sample(N); #0<x<1.2cm
yi = 0 + 2*pi*random_sample(N); #0<y<2*pi

Vi = pointPotential(x0,y0,sigma,xi,yi);

Vtot = (2.*2./N)*sum(Vi) #range is 2 in x and y
print Vtot
# Out:
# 71.2000000013
