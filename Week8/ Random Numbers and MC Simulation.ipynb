# %%
import numpy.random
#numpy.random?

# %%
#print 5 uniformly distributed numbers between 0 and 1
print numpy.random.random(5)

#print another 5... should be different since the seed is different
print numpy.random.random(5)
#computer's clock is used to set the seed
# Out:
# [ 0.89003751  0.18698225  0.29222313  0.22613022  0.98326942]
# [  6.92349301e-01   3.12807807e-04   5.86386910e-02   3.51541181e-01
#    4.49381160e-01]

# %%
#lets change the seed
numpy.random.seed(4242)

#now print 5 random numbers again
print "Using seed = 4242:"
print numpy.random.random(5)
# Out:
# Using seed = 4242:
# [ 0.32494949  0.94041458  0.91400794  0.28650938  0.78180262]

# %%
#lets change the seed to none now
numpy.random.seed(None)

#now print 5 random numbers again
print "Using seed = None:"
print numpy.random.random(5)
# Out:
# Using seed = None:
# [ 0.56453211  0.33064425  0.48502038  0.91782535  0.96895186]

# %%
#lets change the seed back to 4242
numpy.random.seed(4242)

#now print 5 random numbers again
print "Using seed = 4242, we should get the same numbers as before"
print numpy.random.random(5)
# Out:
# Using seed = 4242, we should get the same numbers as before
# [ 0.32494949  0.94041458  0.91400794  0.28650938  0.78180262]

# %%
#reset the seed
numpy.random.seed(None)
z = numpy.random.random(100000)
hist(z,100,normed=True)
plot([0,1.], [1.,1.],"r-",lw=3)
xlabel("x", fontsize=20)
ylabel("Sample Probability", fontsize=20)
show()

# %% [markdown]
# Example 1: Analytic Inverse CDF Transform
# ==

# %%
x = arange(0.,pi+0.001,0.001)
f = lambda x: sin(x)/2
F = lambda x: (cos(0)-cos(x))/2
    
plot(x,f(x),label='True Distribution',lw=3)
plot(x,F(x),label='Cumulative function',lw=3)

xlim(0,3.5)
ylim(0,1.1)

legend(loc=0)
show()

# %%
#number of samples
N=10000

#N random numbers between 0 and 1
z = numpy.random.random_sample(N);

#inverse CDF
Finv = lambda z: arccos(cos(0)-2*z)
    
#samples x values
xsamples = Finv(z);

#how do they compare to the original?
hist(xsamples,50,normed=True,label='Sampled Distribution')
plot (x,f(x),label='True Distribution',lw=3,color='red')

xlim(0,pi)
ylim(0,0.7)

legend(loc=0)
show()

# %%
#hist?

# %% [markdown]
# Exercise 1. Exponential function - analytic
# =

# %% [markdown]
# a)
# -

# %%
x = arange(0,1000+0.01,0.01)
y = 1
g = lambda x: y*exp(-y*x)
G = lambda x: -exp(-y*x)

#number of samples
N=10000

#N random numbers between 0 and 1
z = numpy.random.random_sample(N);

#inverse CDF
Ginv = lambda z: -log(-y*z)
#samples x values
xsamples = Ginv(z)

# %% [markdown]
# b)
# -

# %%
y=1
plot(x,g(x),label='True Distribution',lw=3)
plot(x,G(x),label='Cumulative function',lw=3)

xlim(0,5.)
ylim(-1.5,1.5)

legend(loc=0)
show()

# %% [markdown]
# c)
# -

# %%
hist(xsamples,50,normed=True,label='Sampled Distribution')
plot (x,g(x),label='True Distribution',lw=3,color='red')

xlim(0,5.)
ylim(-3,3.)

legend(loc=0)
show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-60-ef6430eaaad8> in <module>()
# ----> 1 hist(xsamples,50,normed=True,label='Sampled Distribution')
#       2 plot (x,g(x),label='True Distribution',lw=3,color='red')
#       3
#       4 xlim(0,5.)
#       5 ylim(-3,3.)
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/pyplot.pyc in hist(x, bins, range, normed, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, hold, **kwargs)
#    2670                       histtype=histtype, align=align, orientation=orientation,
#    2671                       rwidth=rwidth, log=log, color=color, label=label,
# -> 2672                       stacked=stacked, **kwargs)
#    2673         draw_if_interactive()
#    2674     finally:
#
# ...

# %% [markdown]
# Exercise 2. Exponential function - numerical
# =

# %% [markdown]
# a)
# -

# %%
#cumsum?
#searchsorted?

# %%
x = arange(0,1000+0.01,0.01)
y = 1
g = lambda x: y*exp(-y*x)
dist = []
for i in x:
    dist.append(g(i))
sum_dist = np.cumsum(dist)
normal = sum_dist/sum(dist)
z= random.uniform(0,1)
print z
index = np.searchsorted(normal,z)
print index
value = normal[index]
print value
# Out:
# 0.478781285107
# 65
# 0.483148665508

# %% [markdown]
# b)
# -

# %%
plot(x,g(x),label='True Distribution',lw=3,color='red')
plot(x,normal,label='Cumulative function',lw=3, color='orange')
hist(value,50,normed=True,label='Sampled Distribution')
xlim(0,5.)
ylim(-2,2)

legend(loc=0)
show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-194-7cf08c5da788> in <module>()
#       2 plot(x,g(x),label='True Distribution',lw=3,color='red')
#       3 plot(x,normal,label='Cumulative function',lw=3, color='orange')
# ----> 4 hist(value,50,normed=True,label='Sampled Distribution')
#       5 xlim(0,5.)
#       6 ylim(-2,2)
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/pyplot.pyc in hist(x, bins, range, normed, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, hold, **kwargs)
#    2670                       histtype=histtype, align=align, orientation=orientation,
#    2671                       rwidth=rwidth, log=log, color=color, label=label,
# -> 2672                       stacked=stacked, **kwargs)
#    2673         draw_if_interactive()
#    2674     finally:
#
# ...

# %% [markdown]
# c)
# -

# %%
N= 10000
def distribute1D(x,prob,N):
    sum_dist = np.cumsum(prob)
    normal = sum_dist/sum(prob)
    
    z = zeros(N, float)
    
    for i in range(N):
        z[i] = random.uniform(0,1)
        
    index = zeros(N,int)
    
    for i in range(N):
        index[i] = np.searchsorted(normal,z[i])
        
    value = zeros(N,float)
    
    for i in range(N):
        value[i] = x[index[i]]
        
    return value

# %%
x = arange(0,1000+0.01,0.01)
y = 1
g = lambda x: y*exp(-y*x)
dist = []
for i in x:
    dist.append(g(i))

# %% [markdown]
# Exercise 3. Quantum double-slit experiment
# =

# %% [markdown]
# a)
# -

# %%
d = 15*10**(-6) #meters
a = 10*10**(-6) #meters
L = 1 #meters
y = 632.8*10**(-9) #meters
x = arange(-.2,.20,.001)
b = ((pi*a*x)/(y*L))
I = lambda x: (sin(b)/(b))**2*(cos(2*pi*d*x/(y*L))**2)
plot(x,I(x))
show()

# %%
Prob_Dist = I(x)


Sum_Prob_Dist = np.cumsum(Prob_Dist)
Norm_Prob_Dist = Sum_Prob_Dist/sum(Prob_Dist)

photons = distribute1D(x,Prob_Dist,10000)

# %% [markdown]
# b)
# -

# %%
n = hist(photons,50,normed=True,label = "Sampled Distribution")

plot(x,I(x),'r-', label = "True Distribution")

legend(loc=0)
show()

# %% [markdown]
# c)
# -

# %%
photons = distribute1D(x,Prob_Dist,1)
n = hist(photons,50,normed=True,label = "Sampled Distribution of 1 photon")

photons1 = distribute1D(x,Prob_Dist,10)
n = hist(photons1,50,normed=True,label = "Sampled Distribution of 10 photon")

photons2 = distribute1D(x,Prob_Dist,100)
n = hist(photons2,50,normed=True,label = "Sampled Distribution of 100 photon")

photons3 = distribute1D(x,Prob_Dist,1000)
n = hist(photons3,50,normed=True,label = "Sampled Distribution of 1000 photon")

photons4 = distribute1D(x,Prob_Dist,10000)
n = hist(photons4,50,normed=True,label = "Sampled Distribution of 10000 photon")
legend(loc=0)
show()
