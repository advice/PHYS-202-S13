# %%
import numpy.random
numpy.random?

# %%
#print 5 uniformly distributed numbers between 0 and 1
print numpy.random.random(5)

#print another 5... should be different since the seed is different
print numpy.random.random(5)
#computer's clock is used to set the seed
# Out:
# [ 0.17677701  0.05170938  0.29643264  0.32108455  0.41782977]
# [ 0.38374214  0.42828277  0.29443492  0.2459123   0.82190366]

# %%
#lets change the seed
numpy.random.seed(4242)

#now print 5 random numbers again
print "Using seed = 4242:"
print numpy.random.random(5)
# Out:
# Using seed = 4242:
# [ 0.32494949  0.94041458  0.91400794  0.28650938  0.78180262]

# %%
#lets change the seed to none now
numpy.random.seed(None)

#now print 5 random numbers again
print "Using seed = None:"
print numpy.random.random(5)
# Out:
# Using seed = None:
# [ 0.47799938  0.78656718  0.95817338  0.64840465  0.54425785]

# %%
#lets change the seed back to 4242
numpy.random.seed(4242)

#now print 5 random numbers again
print "Using seed = 4242, we should get the same numbers as before"
print numpy.random.random(5)
# Out:
# Using seed = 4242, we should get the same numbers as before
# [ 0.32494949  0.94041458  0.91400794  0.28650938  0.78180262]

# %%
#reset the seed
numpy.random.seed(None)
z = numpy.random.random(100000)
hist(z,100,normed=True)
plot([0,1.], [1.,1.],"r-",lw=3)
xlabel("x", fontsize=20)
ylabel("Sample Probability", fontsize=20)
show()

# %% [markdown]
# Example 1: Analytic Inverse CDF Transform
# ==

# %%
x = arange(0.,pi+0.001,0.001)
f = lambda x: sin(x)/2
F = lambda x: (cos(0)-cos(x))/2
    
plot(x,f(x),label='True Distribution',lw=3)
plot(x,F(x),label='Cumulative function',lw=3)

xlim(0,3.5)
ylim(0,1.1)

legend(loc=0)
show()

# %%
#number of samples
N=10000

#N random numbers between 0 and 1
z = numpy.random.random_sample(N);

#inverse CDF
Finv = lambda z: arccos(cos(0)-2*z)
    
#samples x values
xsamples = Finv(z);

#how do they compare to the original?
hist(xsamples,50,normed=True,label='Sampled Distribution')
plot (x,f(x),label='True Distribution',lw=3,color='red')

xlim(0,pi)
ylim(0,0.7)

legend(loc=0)
show()

# %%
hist?

# %% [markdown]
# Exercise 1. Exponential function - analytic
# =

# %% [markdown]
# a)
# -

# %%
x = arange(0,1000+0.01,0.01)
y = 1
g = lambda x: y*exp(-y*x)
G = lambda x: -exp(-y*x)

#number of samples
N=10000

#N random numbers between 0 and 1
z = numpy.random.random_sample(N);

#inverse CDF
Ginv = lambda z: -log(-y*z)
#samples x values
xsamples = Ginv(z)
# Out:
# -c:13: RuntimeWarning: invalid value encountered in log

# %% [markdown]
# b)
# -

# %%
y=1
plot(x,g(x),label='True Distribution',lw=3)
plot(x,G(x),label='Cumulative function',lw=3)

xlim(0,5.)
ylim(-1.5,1.5)

legend(loc=0)
show()

# %% [markdown]
# c)
# -

# %%
hist(xsamples,50,normed=True,label='Sampled Distribution')
plot (x,g(x),label='True Distribution',lw=3,color='red')

xlim(0,5.)
ylim(-3,3.)

legend(loc=0)
show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-ef6430eaaad8> in <module>()
# ----> 1 hist(xsamples,50,normed=True,label='Sampled Distribution')
#       2 plot (x,g(x),label='True Distribution',lw=3,color='red')
#       3
#       4 xlim(0,5.)
#       5 ylim(-3,3.)
#
# /Library/Frameworks/EPD64.framework/Versions/7.3/lib/python2.7/site-packages/matplotlib/pyplot.py in hist(x, bins, range, normed, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, hold, **kwargs)
#    2330         ax.hold(hold)
#    2331     try:
# -> 2332         ret = ax.hist(x, bins, range, normed, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, **kwargs)
#    2333         draw_if_interactive()
#    2334     finally:
#
# /Library/Frameworks/EPD64.framework/Versions/7.3/lib/python2.7/site-packages/matplotlib/axes.py in hist(self, x, bins, range, normed, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, **kwargs)
#    7658             # this will automatically overwrite bins,
#    7659             # so that each histogram uses the same bins
# -> 7660             m, bins = np.histogram(x[i], bins, weights=w[i], **hist_kwargs)
#    7661             if normed:
#    7662                 db = np.diff(bins)
#
# /Library/Frameworks/EPD64.framework/Versions/7.3/lib/python2.7/site-packages/numpy/lib/function_base.py in histogram(a, bins, range, normed, weights, density)
#     156         if (mn > mx):
#     157             raise AttributeError(
# --> 158                 'max must be larger than min in range parameter.')
#     159
#     160     if not iterable(bins):
#
# AttributeError: max must be larger than min in range parameter.

# %% [markdown]
# Exercise 2. Exponential function - numerical
# =

# %% [markdown]
# a)
# -

# %%
#cumsum?
#searchsorted?

# %%
x = arange(0,1000+0.01,0.01)
y = 1
g = lambda x: y*exp(-y*x)
dist = []
for i in x:
    dist.append(g(i))
sum_dist = np.cumsum(dist)
normal = sum_dist/sum(dist)
z= random.uniform(0,1)
print z
index = np.searchsorted(normal,z)
print index
value = normal[index]
print value
# Out:
# 0.404189865189
# 51
# 0.40547945203

# %% [markdown]
# b)
# -

# %%
hist(xsamples,50,normed=True,label='Sampled Distribution')
plot(x,g(x),label='True Distribution',lw=3,color='red')
plot(x,normal,label='Cumulative function',lw=3, color='orange')

xlim(0,5.)
ylim(-1.5,1.5)

legend(loc=0)
show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-1dc9cadbdbdd> in <module>()
# ----> 1 hist(xsamples,10,normed=True,label='Sampled Distribution')
#       2 plot(x,g(x),label='True Distribution',lw=3,color='red')
#       3 plot(x,normal,label='Cumulative function',lw=3, color='orange')
#       4
#       5 xlim(0,5.)
#
# /Library/Frameworks/EPD64.framework/Versions/7.3/lib/python2.7/site-packages/matplotlib/pyplot.py in hist(x, bins, range, normed, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, hold, **kwargs)
#    2330         ax.hold(hold)
#    2331     try:
# -> 2332         ret = ax.hist(x, bins, range, normed, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, **kwargs)
#    2333         draw_if_interactive()
#    2334     finally:
#
# /Library/Frameworks/EPD64.framework/Versions/7.3/lib/python2.7/site-packages/matplotlib/axes.py in hist(self, x, bins, range, normed, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, **kwargs)
#    7658             # this will automatically overwrite bins,
#    7659             # so that each histogram uses the same bins
# -> 7660             m, bins = np.histogram(x[i], bins, weights=w[i], **hist_kwargs)
#    7661             if normed:
#    7662                 db = np.diff(bins)
#
# /Library/Frameworks/EPD64.framework/Versions/7.3/lib/python2.7/site-packages/numpy/lib/function_base.py in histogram(a, bins, range, normed, weights, density)
#     156         if (mn > mx):
#     157             raise AttributeError(
# --> 158                 'max must be larger than min in range parameter.')
#     159
#     160     if not iterable(bins):
#
# AttributeError: max must be larger than min in range parameter.

# %% [markdown]
# c)
# -

# %%
def distribute1D(x,prob,N):
    sum_dist = np.cumsum(dist)
    normal = sum_dist/sum(dist)
    z = []
    for i in range(N):
        z.append(random.uniform(0,1))
    index = []
    for i in range(N):
        index.append(np.searchsorted(normal,z))
    value = []
    for i in range(N):
        value.append(normal[index(i)])
    return value

# %%
x = arange(0,1000+0.01,0.01)
y = 1
g = lambda x: y*exp(-y*x)
dist = []
for i in x:
    dist.append(g(i))

# %% [markdown]
# Exercise 3. Quantum double-slit experiment
# =

# %% [markdown]
# a)
# -

# %%
d = 15*10**(-6) #meters
a = 10*10**(-6) #meters
L = 1 #meters
y = 632.8*10**(-9) #meters
x = arange(-.2,.21,.01)
b = (a*x)/(y*L)
I = lambda x: sin((pi*b)/(pi*b))**2 * cos(2*pi*d*x/(y*L))**2
Prob_Dist = []
for i in x:
    Prob_Dist.append(I(i))

photons = distribute1D(x,Prob_Dist,10000)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-c466ae0bc441> in <module>()
#      10     Prob_Dist.append(I(i))
#      11
# ---> 12 photons = distribute1D(x,Prob_Dist,10000)
#
# <ipython-input-21-2f4bb1b03ac2> in distribute1D(x, prob, N)
#      10     value = []
#      11     for i in range(N):
# ---> 12         value.append(normal[index(i)])
#      13     return value
#
# TypeError: 'list' object is not callable

# %% [markdown]
# b)
# -

# %%
x = arange(-.2,.21,.01)
plot(x,Prob_Dist, label = "True Distribution")
hist(photons,50,m=normed=True,label = "Sampled Dstribution")
legend(loc=0)
show()

# %% [markdown]
# c)
# -
