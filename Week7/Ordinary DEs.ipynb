# %%
g = 9.8
l = 0.5
th0 = 20.*pi/180

t = arange(0.,10.+0.01,0.01)
theta_app = lambda t: th0*cos(sqrt(g/l)*t)
    
plot(t,theta_app(t))
show()

# %%
def deriv(theta_current,t):
    g = 9.8
    l = 0.5
    theta = theta_current[0]
    omega = theta_current[1]
    dtheta = omega
    domega = -(g/l)*sin(theta)
    return array([dtheta,domega])

# %%
from scipy.integrate import odeint

# %%
t = arange(0.,10. +0.01,0.01)

omega0 = 0.
theta_init = array([th0,omega0])
theta = odeint(deriv,theta_init,t)

# %%
theta.shape
# Out:
# (1001, 2)

# %%
plot(t,theta_app(t), 'b-', t,theta[:,0], 'r--')
show()

# %%
th0 = 50.*pi/180

theta_init = array([th0,omega0])
theta = odeint(deriv,theta_init,t)

plot(t,theta_app(t),'b-', t,theta[:,0],'r--')
show()

# %% [markdown]
# Exercises
# ==

# %% [markdown]
# 1.
# -

# %%
th0 = 0

theta_init = array([th0,omega0])
theta = odeint(deriv,theta_init,t)

plot(t,theta_app(t),'b-', t,theta[:,0],'r--')
xlim(0,pi+.1,.1)
theta = array([0,1,2,3,4]) #seting the right number of tick marks
my_xticks=['$0$','$-\pi/4$','$\pi/2$','$3\pi/4$','$\pi$']
xticks(theta, my_xticks)

###################################################
th0 = pi/4

theta_init = array([th0,omega0])
theta = odeint(deriv,theta_init,t)

plot(t,theta_app(t),'b-', t,theta[:,0],'r--')
xlim(0,pi+.1,.1)
theta = array([0,1,2,3,4]) #seting the right number of tick marks
my_xticks=['$0$','$-\pi/4$','$\pi/2$','$3\pi/4$','$\pi$']
xticks(theta, my_xticks)

###################################################
th0 = pi/2

theta_init = array([th0,omega0])
theta = odeint(deriv,theta_init,t)

plot(t,theta_app(t),'b-', t,theta[:,0],'r--')
xlim(0,pi+.1,.1)
theta = array([0,1,2,3,4]) #seting the right number of tick marks
my_xticks=['$0$','$-\pi/4$','$\pi/2$','$3\pi/4$','$\pi$']
xticks(theta, my_xticks)

###################################################
th0 = 3*pi/4

theta_init = array([th0,omega0])
theta = odeint(deriv,theta_init,t)

plot(t,theta_app(t),'b-', t,theta[:,0],'r--')
xlim(0,pi+.1,.1)
theta = array([0,1,2,3,4]) #seting the right number of tick marks
my_xticks=['$0$','$-\pi/4$','$\pi/2$','$3\pi/4$','$\pi$']
xticks(theta, my_xticks)

###################################################
th0 = pi

theta_init = array([th0,omega0])
theta = odeint(deriv,theta_init,t)

plot(t,theta_app(t),'b-', t,theta[:,0],'r--')
xlim(0,pi+.1,.1)
theta = array([0,1,2,3,4]) #seting the right number of tick marks
my_xticks=['$0$','$-\pi/4$','$\pi/2$','$3\pi/4$','$\pi$']
xticks(theta, my_xticks)
show()

# %% [markdown]
# 2.
# -

# %%
#theta vs t
th0 = pi*(0.95)

theta_init = array([th0,omega0])
theta = odeint(deriv,theta_init,t)

plot(t,theta_app(t),'b-', t,theta[:,0],'r--')
xlim(0,pi+.1,.1)
theta = array([0,1,2,3,4]) 
my_xticks=['$0$','$-\pi/4$','$\pi/2$','$3\pi/4$','$\pi$']
xticks(theta, my_xticks)
show()

# %%
#omega vs t
th0 = pi*(0.95)

theta_init = array([th0,omega0])
theta = odeint(deriv,theta_init,t)

plot(t,theta_app(t),'b-', t,theta[:,1],'r--')
xlim(0,pi+.1,.1)
theta = array([0,1,2,3,4]) 
my_xticks=['$0$','$-\pi/4$','$\pi/2$','$3\pi/4$','$\pi$']
xticks(theta, my_xticks)
show()

# %%
#Phase plot
th0 = pi*(0.95)

theta_init = array([th0,omega0])
theta = odeint(deriv,theta_init,t)

plot(theta[:,0],theta[:,1],'r-')

show()

# %% [markdown]
# 3.
# -

# %%
th0 = 0.95*pi
theta_init = array([th0,omega0])
theta = odeint(deriv,theta_init,t)

E = g*(l-l*sin(theta[:,0])) +.5*(l*theta[:,1])**2
plot(t,E)
show()
